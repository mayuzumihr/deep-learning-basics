# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

torch.cuda.empty_cache()

# %%
model_path = "./model"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)

prompt = "今日のおすすめは、"
inputs = tokenizer(prompt, return_tensors="pt", padding=True)

output = model.generate(
  input_ids = inputs['input_ids'],
  attention_mask = inputs['attention_mask'],
  max_length = 100,                       # 生成する文章の最大長を指定
  num_return_sequences = 10,              # 生成する文の数
  no_repeat_ngram_size = 2,               # n-gramの繰り返しを避ける
  top_k = 50,                             # 上位k個の単語からランダムに選ぶ
  top_p = 0.95,                           # 上位確率pの単語からランダムに選ぶ
  temperature = 0.95,                     # ランダム性の制御
  do_sample = True,                       # サンプリングを有効にする
  pad_token_id = tokenizer.eos_token_id   # モデルが生成を終了できるようにする
)

for generated_text in output:
  print(tokenizer.decode(generated_text, skip_special_tokens=True))
# Out:
# 今日のおすすめは、生で食べたり、おでん、煮物など、食後のデザートに最適の「生パスタ」です。パセリ、ニンニク、カキ、チーズ、タマネギ、卵、ナッツなどを使い、パテで巻いてから、 ソースやお酒、ミルクなどを合わせてからお召し上がり下さい。今回は、「生ピッツァ」のレシピをご紹介。トマト、玉ねぎ、トマトペースト、
# 今日のおすすめは、・映画『マトリックス』をフルで楽しむ ・『ブラック・スワン』の魅力とは? 先日の公開前より、映画鑑賞や舞台挨拶などで、 世間で絶賛されている、 『マトリクス・オブ・ザ・ナイト』。 その人気からか、2月1日と2日、 東京・渋谷「渋谷シネクイント」、 2月9日・13日の1日間、梅田ブルク7に、 3
# 今日のおすすめは、#お得なキャンペーン情報 から、 #【期間限定】おためしセット! ・お子様連れ・家族みんなで、#ポエ
# 今日のおすすめは、・美味しいご飯を食べること... ・ビールの飲み方... 「ビールが一番!」という人もいると思いますが、やはり日本酒でお腹が一杯になるお酒はお薦めです。そんな、飲みたい時に飲めるおつまみをランキング形式で紹介します。 アサヒ...お酢がオススメですね。ビールを飲みながら、日本ならではの料理を楽しみながらビールはいかが? さて、アサヒビールの特徴といえば
# 今日のおすすめは、#仮面ライダー #キュウレンジャー さんの「お母さんのおなか」です。 仮面ライダーファンは「仮面ライダー」が好きな人も多いのではないでしょうか? その人気ぶりは勿論、お子様たちの感受性や可能性を無限大に広げてくれるのが、今回紹介する「オプティマス」シリーズの魅力でもあります。今回はそんな「大人のオザケン」の子供好きさんが大注目する、大人向けの
# 今日のおすすめは、あなたにぴったりのお酒・焼酎を紹介。今週の1週間に起こった出来事を振り返る「今年の出来事」。皆さんはどんな一年を過ごしましたか?皆様にぴっと合うお酒をセレクトし、ご紹介していきます!今回は「ビールで乾杯」(o47)をご提案します。 おつまみメニューに「シャンパーニュ」も初登場。こちらは、2日限定の
# 今日のおすすめは、とっても美味しい「とろけるチーズケーキ」。 とんこつラーメンの『ととこ・にこる』が、ついに復活しました。とんでもない「旨」な味わいがクセになる、とっておきの2品です。「チーズ」の食べ比べは絶品。さて、チーズとチーズのおすすめは何ですか?と聞いたら、真っ先に真っ赤な答えが返ってきた
# 今日のおすすめは、人気漫画・映画『キャプテン翼』の実写映画化が決定した『ダークナイトライジング』。原作・原作者の小山力也さんが監修を務めていることでも話題になっている本作が、今夏公開される。『ザ・スパイダース/キャプテン・アメリカ』でスパイダーマン役として主演を務める小雪と、その人気キャラのキャプテンハルク役を演じる水原希子が登場する。この物語は、『ダーク・シャドウ』以来13年ぶりに映画化される、アメリカの
# 今日のおすすめは、日焼け止めを塗って 、 髪の毛のトリートメントをして スッキリする。 こんにちは もうすぐ、ハロウィンですね♡ イベントが盛りだくさんのこの時期に、素敵なコーディネートをさせて頂きます!! 10月31日(水)はイベントも沢山ありますので、是非お越し下さい♪ ☆【10月のイベント】 先月
# 今日のおすすめは、なんでこの手のスイーツに目を止めたのだろうか。 そう、僕はチョコレートが好きで、何を食べてもカカオの味がする。チョコレートには様々な種類のチョコレートが揃っている。けれど、カ カオは食べ応えがあるし、食べるたびにチョコとフルーティーな香りに癒される。だからこそ、「カワイイ」って言うのだろう。そして、ここ最近、その美味しさにハマってるんだ
