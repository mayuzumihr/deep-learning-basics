# %%
import MeCab
import ipadic

# %%
tagger = MeCab.Tagger()
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger()
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger()
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)
# Out:
# 吾輩	ワガハイ	ワガハイ	我が輩	代名詞			0
# は	ワ	ハ	は	助詞-係助詞
# 猫	ネコ	ネコ	猫	名詞-普通名詞-一般			1
# で	デ	ダ	だ	助動詞	助動詞-ダ	連用形-一般
# ある	アル	アル	有る	動詞-非自立可能	五段-ラ行	終止形-一般	1
# 。			。	補助記号-句点
# 名前	ナマエ	ナマエ	名前	名詞-普通名詞-一般			0
# は	ワ	ハ	は	助詞-係助詞
# まだ	マダ	マダ	未だ	副詞			1
# ない	ナイ	ナイ	無い	形容詞-非自立可能	形容詞	終止形-一般	1
# 。			。	補助記号-句点
# EOS
#
# 吾輩	ワガハイ	ワガハイ	我が輩	代名詞			0
# は	ワ	ハ	は	助詞-係助詞
# 猫	ネコ	ネコ	猫	名詞-普通名詞-一般			1
# で	デ	ダ	だ	助動詞	助動詞-ダ	連用形-一般
# ある	アル	アル	有る	動詞-非自立可能	五段-ラ行	終止形-一般	1
# 。			。	補助記号-句点
# 名前	ナマエ	ナマエ	名前	名詞-普通名詞-一般			0
# は	ワ	ハ	は	助詞-係助詞
# まだ	マダ	マダ	未だ	副詞			1
# ない	ナイ	ナイ	無い	形容詞-非自立可能	形容詞	終止形-一般	1
# 。			。	補助記号-句点
# EOS
#
# 吾輩	ワガハイ	ワガハイ	我が輩	代名詞			0
# は	ワ	ハ	は	助詞-係助詞
# 猫	ネコ	ネコ	猫	名詞-普通名詞-一般			1
# で	デ	ダ	だ	助動詞	助動詞-ダ	連用形-一般
# ある	アル	アル	有る	動詞-非自立可能	五段-ラ行	終止形-一般	1
# 。			。	補助記号-句点
# 名前	ナマエ	ナマエ	名前	名詞-普通名詞-一般			0
# は	ワ	ハ	は	助詞-係助詞
# まだ	マダ	マダ	未だ	副詞			1
# ない	ナイ	ナイ	無い	形容詞-非自立可能	形容詞	終止形-一般	1
# 。			。	補助記号-句点
# EOS

# %%
print(ipadic.DICDIR)

tagger = MeCab.Tagger(f'-d "{ipadic.DICDIR}"')
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Odump -d "{ipadic.DICDIR}"')
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Owakati -d "{ipadic.DICDIR}"')
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Ochasen -d "{ipadic.DICDIR}"')
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Oyomi -d "{ipadic.DICDIR}"')
text = "吾輩は猫である。名前はまだない。"
result = tagger.parse(text)
print(result)
# Out:
# d:\Python\Python-3.8.10\lib\site-packages\ipadic\dicdir
# 吾輩	名詞,代名詞,一般,*,*,*,吾輩,ワガハイ,ワガハイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 猫	名詞,一般,*,*,*,*,猫,ネコ,ネコ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# ある	助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
# 名前	名詞,一般,*,*,*,*,名前,ナマエ,ナマエ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# まだ	副詞,助詞類接続,*,*,*,*,まだ,マダ,マダ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# 。	記号,句点,*,*,*,*,。,。,。
# EOS
#
# 0 BOS BOS/EOS,*,*,*,*,*,*,*,* 0 0 0 0 0 0 2 1 0.000000 0.000000 0.000000 0
# 2 吾輩 名詞,代名詞,一般,*,*,*,吾輩,ワガハイ,ワガハイ 0 6 1306 1306 59 2 0 1 0.000000 0.000000 0.000000 4130
# 7 は 助詞,係助詞,*,*,*,*,は,ハ,ワ 6 9 261 261 16 6 0 1 0.000000 0.000000 0.000000 4556
# 8 猫 名詞,一般,*,*,*,*,猫,ネコ,ネコ 9 12 1285 1285 38 2 0 1 0.000000 0.000000 0.000000 10275
# 17 で 助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ 12 15 458 458 25 6 0 1 0.000000 0.000000 0.000000 12578
# 26 ある 助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル 15 21 403 403 25 6 0 1 0.000000 0.000000 0.000000 6945
# 30 。 記号,句点,*,*,*,*,。,。,。 21 24 8 8 7 3 0 1 0.000000 0.000000 0.000000 4003
# ...

# %%
tagger = MeCab.Tagger()
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger()
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger()
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)
# Out:
# 葬送	ソーソー	ソウソウ	葬送	名詞-普通名詞-一般			0
# の	ノ	ノ	の	助詞-格助詞
# フリー	フリー	フリー	フリー-free	名詞-普通名詞-形状詞可能			2
# レン	レン	レン	レン	名詞-固有名詞-人名-一般			1
# EOS
#
# 葬送	ソーソー	ソウソウ	葬送	名詞-普通名詞-一般			0
# の	ノ	ノ	の	助詞-格助詞
# フリー	フリー	フリー	フリー-free	名詞-普通名詞-形状詞可能			2
# レン	レン	レン	レン	名詞-固有名詞-人名-一般			1
# EOS
#
# 葬送	ソーソー	ソウソウ	葬送	名詞-普通名詞-一般			0
# の	ノ	ノ	の	助詞-格助詞
# フリー	フリー	フリー	フリー-free	名詞-普通名詞-形状詞可能			2
# レン	レン	レン	レン	名詞-固有名詞-人名-一般			1
# EOS

# %%
print(ipadic.DICDIR)

tagger = MeCab.Tagger(f'-d "{ipadic.DICDIR}"')
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Odump -d "{ipadic.DICDIR}"')
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Owakati -d "{ipadic.DICDIR}"')
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Ochasen -d "{ipadic.DICDIR}"')
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

tagger = MeCab.Tagger(f'-Oyomi -d "{ipadic.DICDIR}"')
text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)
# Out:
# d:\Python\Python-3.8.10\lib\site-packages\ipadic\dicdir
# 葬送	名詞,一般,*,*,*,*,葬送,ソウソウ,ソーソー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フリー	名詞,一般,*,*,*,*,フリー,フリー,フリー
# レン	名詞,固有名詞,人名,名,*,*,レン,レン,レン
# EOS
#
# 0 BOS BOS/EOS,*,*,*,*,*,*,*,* 0 0 0 0 0 0 2 1 0.000000 0.000000 0.000000 0
# 3 葬送 名詞,一般,*,*,*,*,葬送,ソウソウ,ソーソー 0 6 1285 1285 38 2 0 1 0.000000 0.000000 0.000000 5190
# 8 の 助詞,連体化,*,*,*,*,の,ノ,ノ 6 9 368 368 24 6 0 1 0.000000 0.000000 0.000000 5564
# 12 フリー 名詞,一般,*,*,*,*,フリー,フリー,フリー 9 18 1285 1285 38 7 0 1 0.000000 0.000000 0.000000 5411
# 72 レン 名詞,固有名詞,人名,名,*,*,レン,レン,レン 18 24 1291 1291 44 7 0 1 0.000000 0.000000 0.000000 10540
# 92 EOS BOS/EOS,*,*,*,*,*,*,*,* 24 24 0 0 0 0 3 1 0.000000 0.000000 0.000000 9192
#
# 葬送 の フリー レン
#
# 葬送	ソウソウ	葬送	名詞-一般
# の	ノ	の	助詞-連体化
# フリー	フリー	フリー	名詞-一般
# レン	レン	レン	名詞-固有名詞-人名-名
# EOS
#
# ソウソウノフリーレン

# %%
tagger = MeCab.Tagger(f'-d "{ipadic.DICDIR}"')

text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

text = "薬屋のひとりごと"
result = tagger.parse(text)
print(result)

text = "俺の妹がこんなに可愛いわけがない"
result = tagger.parse(text)
print(result)

text = "異世界おじさん"
result = tagger.parse(text)
print(result)

text = "お隣の天使様にいつの間にか駄目人間にされていた件"
result = tagger.parse(text)
print(result)

text = "時々ボソッとロシア語でデレる隣のアーリャさん"
result = tagger.parse(text)
print(result)
# Out:
# 葬送	名詞,一般,*,*,*,*,葬送,ソウソウ,ソーソー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# フリー	名詞,一般,*,*,*,*,フリー,フリー,フリー
# レン	名詞,固有名詞,人名,名,*,*,レン,レン,レン
# EOS
#
# 薬屋	名詞,固有名詞,地域,一般,*,*,薬屋,クスリヤ,クスリヤ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ひとり	名詞,一般,*,*,*,*,ひとり,ヒトリ,ヒトリ
# ごと	名詞,接尾,一般,*,*,*,ごと,ゴト,ゴト
# EOS
#
# 俺	名詞,代名詞,一般,*,*,*,俺,オレ,オレ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 妹	名詞,一般,*,*,*,*,妹,イモウト,イモート
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# こんなに	副詞,助詞類接続,*,*,*,*,こんなに,コンナニ,コンナニ
# 可愛い	形容詞,自立,*,*,形容詞・イ段,基本形,可愛い,カワイイ,カワイイ
# わけ	名詞,非自立,一般,*,*,*,わけ,ワケ,ワケ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# EOS
#
# 異	接頭詞,名詞接続,*,*,*,*,異,イ,イ
# 世界	名詞,一般,*,*,*,*,世界,セカイ,セカイ
# おじさん	名詞,一般,*,*,*,*,おじさん,オジサン,オジサン
# EOS
#
# お隣	名詞,一般,*,*,*,*,お隣,オトナリ,オトナリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 天使	名詞,一般,*,*,*,*,天使,テンシ,テンシ
# 様	名詞,接尾,人名,*,*,*,様,サマ,サマ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# いつの間にか	副詞,一般,*,*,*,*,いつの間にか,イツノマニカ,イツノマニカ
# 駄目	名詞,形容動詞語幹,*,*,*,*,駄目,ダメ,ダメ
# 人間	名詞,一般,*,*,*,*,人間,ニンゲン,ニンゲン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# ...

# %%
tagger = MeCab.Tagger(f'-d "{ipadic.DICDIR}" -u "NEologD.20200910-u.dic"')

text = "葬送のフリーレン"
result = tagger.parse(text)
print(result)

text = "薬屋のひとりごと"
result = tagger.parse(text)
print(result)

text = "俺の妹がこんなに可愛いわけがない"
result = tagger.parse(text)
print(result)

text = "異世界おじさん"
result = tagger.parse(text)
print(result)

text = "お隣の天使様にいつの間にか駄目人間にされていた件"
result = tagger.parse(text)
print(result)

text = "時々ボソッとロシア語でデレる隣のアーリャさん"
result = tagger.parse(text)
print(result)
# Out:
# 葬送のフリーレン	名詞,固有名詞,一般,*,*,*,葬送のフリーレン,ソウソウノフリーレン,ソーソーノフリーレン
# EOS
#
# 薬屋のひとりごと	名詞,固有名詞,一般,*,*,*,薬屋のひとりごと,クスリヤノヒトリゴト,クスリヤノヒトリゴト
# EOS
#
# 俺の妹がこんなに可愛いわけがない	名詞,固有名詞,一般,*,*,*,俺の妹がこんなに可愛いわけがない,オレノイモウトガコンナニカワイイワケガナイ,オレノイモートガコンナニカワイーワケガナイ
# EOS
#
# 異世界おじさん	名詞,固有名詞,一般,*,*,*,異世界おじさん,イセカイオジサン,イセカイオジサン
# EOS
#
# お隣の天使様にいつの間にか駄目人間にされていた件	名詞,固有名詞,一般,*,*,*,お隣の天使様にいつの間にか駄目人間にされていた件,オトナリノテンシサマニイツノマニカダメニンゲンニサレテイタケン,オトナリノテンシサマニイツノマニカダメニンゲンニサレテイタケン
# EOS
#
# 時々	副詞,一般,*,*,*,*,時々,トキドキ,トキドキ
# ボソッ	副詞,助詞類接続,*,*,*,*,ボソッ,ボソッ,ボソッ
# と	助詞,副詞化,*,*,*,*,と,ト,ト
# ロシア語	名詞,固有名詞,一般,*,*,*,ロシア語,ロシアゴ,ロシアゴ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# デレ	名詞,固有名詞,一般,*,*,*,DELE,デレ,デレ
# る	助動詞,*,*,*,文語・リ,体言接続,り,ル,ル
# 隣	名詞,一般,*,*,*,*,隣,トナリ,トナリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# アーリャ	名詞,一般,*,*,*,*,*
# さん	名詞,接尾,人名,*,*,*,さん,サン,サン
# EOS
